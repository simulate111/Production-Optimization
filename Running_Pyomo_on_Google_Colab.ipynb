# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Production-Optimization/blob/main/Running_Pyomo_on_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

import os

try:

  from pyomo.environ import *

except:

    # !pip install idaes-pse --pre

    # !idaes get-extensions --to ./bin

    os.environ['PATH'] += ':bin'
