# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Production-Optimization/blob/main/Circlepacking_empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# All installations must be done every time you re-open a notebook and want to run it. Google colab has many packages already installed, which you normally would need to install such as nympy, scipy , matplotlib, plotly, pandas. Most of these also comes with Anaconda (except plotly)
#
# Adding text and code is done with "+ Code" or "+ Text" Sections can easlily be moved or deleted. To run a code you need to press the play buttom that appears when you move the cursor over a code block.
#
# First we install pyomo (in quite mode). Since you will need to use
# Runtime->Run all if you re-define a pyomo model, we add a try-except construction to the Python code to check if pyomo is already installed. The "!" allows us to run command (as in a terminal).
#
# For this example we need the NLP solver ipopt. This is distributed with the larger package ideas (and now it seems that this solver should be called as ipopt_l1, this may change again).

# %%
#Install pyomo and solvers from the IDAES project
#this installs several solvers like ipopt, cbc, bonmin but takes some time to run
#ipopt is now under the name ipop_l1
try:
  not_first_time == True
except:
  # !pip install idaes-pse --pre
  # !idaes get-extensions --to ./bin
  not_first_time = True
finally:
  print("Pyomo and solvers installed")
# Out:
# Collecting idaes-pse
#   Downloading idaes_pse-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pyomo>=6.9.3 in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (6.9.5)
# Collecting pint>=0.24.1 (from idaes-pse)
#   Downloading pint-0.25.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (3.6.1)
# Requirement already satisfied: numpy<3,>=1 in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (2.0.2)
# Requirement already satisfied: pandas!=2.1.0,<3 in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (1.16.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (1.14.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (3.10.0)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.12/dist-packages (from idaes-pse) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2025.3)
# Collecting flexcache>=0.3 (from pint>=0.24.1->idaes-pse)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.24.1->idaes-pse)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.24.1->idaes-pse) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.24.1->idaes-pse) (4.15.0)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from pyomo>=6.9.3->idaes-pse) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->idaes-pse) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->idaes-pse) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,<3->idaes-pse) (1.17.0)
# Downloading idaes_pse-2.10.0-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 26.2 MB/s eta 0:00:00
# Downloading pint-0.25.2-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.8/306.8 kB 8.9 MB/s eta 0:00:00
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Installing collected packages: flexparser, flexcache, pint, idaes-pse
# Successfully installed flexcache-0.3 flexparser-0.4 idaes-pse-2.10.0 pint-0.25.2
# Getting files...
# Done
# -----------------------------------------------------------------
# IDAES Extensions Build Versions
# =================================================================
# Solvers:  v3.4.2 20240811 ubuntu2204-x86_64
# Library:  v3.4.2 20240811 ubuntu2204-x86_64
#
# =================================================================
# Pyomo and solvers installed

# %% [markdown]
# The problem in compact form:
#
# $ \min \: w \cdot h$
#
# s.t
#
# $x_c \ge r_c \:\: \forall c \in C$
#
# $x_c + r_c \le w \:\: \forall c \in C$
#
# $y_c \ge r_c \:\: \forall c \in C$
#
# $y_c + r_c \le h \:\: \forall c \in C$
#
# $(x_c-x_{c^\prime})^2+(y_c-y_{c^\prime})^2 \ge (r_c+r_{c^\prime})^2 \:\: \forall c,c^{\prime} \in C,c \lt c^{\prime}$
#
# $h,w,x_c,y_c \in \mathbb{R}_{\ge 0}, C=\{c_1,c_2,c_3,c_4\}$
#
#
#
# The radius of the circles, from 1 to 4, are 3, 3, 2 and 3, respectively.
#
# When you are done with the this problem, add a cicle with your name and a radius

# %%
from pyomo.environ import *
import matplotlib.pyplot as plt
#return this cell if you make changes

m=ConcreteModel()
#Sets Set(initialize=,doc='')

#Parameters Param(initialize={key:values},doc='')

#Variables Var(within=NonNegativeReals,doc='') (Starting guesses can be given with initialize={key:values}, usually no need)

#Objective Objective(expr= , sense=minimize, doc='')

#Constraints Constraint(rule= ,doc='')



#m.pprint()

# %%
#Solve in a separate stage, since we need to build the model first. When ready, one cell would do.
#added path to the executable, seems to be necessary
solver = SolverFactory("ipopt_l1",executable="/content/bin/ipopt_l1") #it used to be ipopt...

#solver = SolverFactory("couenne",executable="/content/bin/couenne") #this may take forever with large problems, restrict time using a opt-file
#with open("couenne.opt","w") as file:
#    file.write("time_limit 30")

results = solver.solve(m, keepfiles=False, tee=True)
#m.display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-437618786.py in <cell line: 0>()
#       7 #    file.write("time_limit 30")
#       8
# ----> 9 results = solver.solve(m, keepfiles=False, tee=True)
#      10 #m.display()
#
# /usr/local/lib/python3.12/dist-packages/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     622             initial_time = time.time()
#     623
# --> 624             self._presolve(*args, **kwds)
#     625
#     626             presolve_completion_time = time.time()
#
# /usr/local/lib/python3.12/dist-packages/pyomo/solvers/plugins/solvers/ASL.py in _presolve(self, *args, **kwds)
#     212             self._instance = None
#     213         #
# --> 214         SystemCallSolver._presolve(self, *args, **kwds)
#     215
#     216     def _postsolve(self):
#
# /usr/local/lib/python3.12/dist-packages/pyomo/opt/solver/shellcmd.py in _presolve(self, *args, **kwds)
#     221         self._define_signal_handlers = kwds.pop('use_signal_handling', None)
#     222
# --> 223         OptSolver._presolve(self, *args, **kwds)
#     224
#     225         #
#
# /usr/local/lib/python3.12/dist-packages/pyomo/opt/base/solvers.py in _presolve(self, *args, **kwds)
#     728             write_start_time = time.time()
#     729             (self._problem_files, self._problem_format, self._smap_id) = (
# --> 730                 self._convert_problem(
#     731                     args, self._problem_format, self._valid_problem_formats, **kwds
#     732                 )
#
# /usr/local/lib/python3.12/dist-packages/pyomo/opt/base/solvers.py in _convert_problem(self, args, problem_format, valid_problem_formats, **kwds)
#     780
#     781     def _convert_problem(self, args, problem_format, valid_problem_formats, **kwds):
# --> 782         return convert_problem(
#     783             args, problem_format, valid_problem_formats, self.has_capability, **kwds
#     784         )
#
# /usr/local/lib/python3.12/dist-packages/pyomo/opt/base/convert.py in convert_problem(args, target_problem_type, valid_problem_types, has_capability, **kwds)
#      95                     tmpkw = kwds
#      96                     tmpkw['capabilities'] = has_capability
# ---> 97                     problem_files, symbol_map = converter.apply(*tmp, **tmpkw)
#      98                     return problem_files, ptype, symbol_map
#      99
#
# /usr/local/lib/python3.12/dist-packages/pyomo/solvers/plugins/converter/model.py in apply(self, *args, **kwds)
#     182                     )
#     183                 else:
# --> 184                     (problem_filename, symbol_map_id) = instance.write(
#     185                         filename=problem_filename,
#     186                         format=args[1],
#
# /usr/local/lib/python3.12/dist-packages/pyomo/core/base/block.py in write(self, filename, format, solver_capability, io_options, int_marker)
#    2007                 return True
#    2008
# -> 2009         (filename, smap) = problem_writer(self, filename, solver_capability, io_options)
#    2010         smap_id = id(smap)
#    2011         if not hasattr(self, 'solutions'):
#
# /usr/local/lib/python3.12/dist-packages/pyomo/repn/plugins/nl_writer.py in __call__(self, model, filename, solver_capability, io_options)
#     323                 os.remove(row_fname)
#     324                 os.remove(col_fname)
# --> 325             raise ValueError(
#     326                 "No variables appear in the Pyomo model constraints or"
#     327                 " objective. This is not supported by the NL file interface"
#
# ValueError: No variables appear in the Pyomo model constraints or objective. This is not supported by the NL file interface

# %%
#Code for plotting the solution
figure, axes = plt.subplots()
for c in m.C:
    draw_circle = plt.Circle((m.x[c].value, m.y[c].value),m.r[c] )
    axes.add_artist(draw_circle)
    axes.text(m.x[c].value, m.y[c].value, c,
         horizontalalignment='center', verticalalignment='center')

plt.plot([0, m.w.value],[m.h.value, m.h.value])
plt.plot([m.w.value,m.w.value],[0, m.h.value])
axes.set_aspect(1)

plt.xlim(0,m.w.value+2)
plt.ylim(0,m.h.value+2)
plt.show()

# %%
#Importing using Pandas dataframes from Excel is practical. For a simple Excel file with headers in the first row and data i cells below this works
#(there are many ways to do the same thing)

#import pandas as pd
#
#df = pd.read_excel('circle_data.xlsx') #you need to upload the file to colab each session
#m.C = Set(initialize=df.set_index('circles').index.to_list(),doc='Circles')
#m.r = Param(m.C,initialize=df.set_index('circles')['radius'].to_dict(),doc='Radius of circle')

# %%
#something on dataframes

#df2=df.set_index('circles') #creates a new dataframe that has circles as indices
#df2['radius'] #getting the elements in the column 'radius' as a series
#df2['radies'].to_dict() #convert the series to a dictionary
#df.set_index('circles')['radius'].to_dict() #everything in one step
